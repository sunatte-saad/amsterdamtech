# %%
import pandas as pd
import csv
import json

# %%
voice_df= pd.read_csv('/Users/apple/Downloads/filters.xlsx - VOICE (1).csv')
voice_df.head()
# Out:
#     id           model  transpose               voice_name  speed
# 0  id0  amitabhbachhan         -6  en-GB-ThomasNeural-Male    -20
# 1  id1         BTS_jin          0     en-US-GuyNeural-Male    -30
# 2  id2        amirkhan          1   en-US-BrianNeural-Male    -10
# 3  id3     adolfhitler          0  en-US-AndrewNeural-Male     10
# 4  id4       atifaslam         -6   en-US-BrianNeural-Male    -20

# %%
voice_json=voice_df.to_json(orient='records')
print(voice_json)
# Out:
# [{"id":"id0","model":"amitabhbachhan","transpose":-6,"voice_name":"en-GB-ThomasNeural-Male","speed":-20},{"id":"id1","model":"BTS_jin","transpose":0,"voice_name":"en-US-GuyNeural-Male","speed":-30},{"id":"id2","model":"amirkhan","transpose":1,"voice_name":"en-US-BrianNeural-Male","speed":-10},{"id":"id3","model":"adolfhitler","transpose":0,"voice_name":"en-US-AndrewNeural-Male","speed":10},{"id":"id4","model":"atifaslam","transpose":-6,"voice_name":"en-US-BrianNeural-Male","speed":-20},{"id":"id5","model":"bartsimpson","transpose":-2,"voice_name":"en-US-AvaNeural-Female","speed":10},{"id":"id6","model":"batman","transpose":0,"voice_name":"en-US-ChristopherNeural-Male","speed":0},{"id":"id7","model":"beyonce","transpose":-2,"voice_name":"en-US-MichelleNeural-Female","speed":-10},{"id":"id8","model":"biden","transpose":1,"voice_name":"en-US-SteffanNeural-Male","speed":0},{"id":"id9","model":"billgates","transpose":1,"voice_name":"en-US-GuyNeural-Male","speed":-10},{"id":"id10","model":
# ...

# %%
with open ("voice_clone_data.json","w") as f:
      f.write(voice_json)
